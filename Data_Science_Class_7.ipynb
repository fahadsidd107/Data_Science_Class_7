# %% [markdown]
# # Data Science Class 6

# %%
import pandas as pd
data = pd.read_csv('netflix_titles.csv')
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # LOC - Label Based Selection

# %%
# data.loc[<row label>,<column label>]
data.loc[:,'title']
# Out:
# 0        Dick Johnson Is Dead
# 1               Blood & Water
# 2                   Ganglands
# 3       Jailbirds New Orleans
# 4                Kota Factory
#                 ...
# 8802                   Zodiac
# 8803              Zombie Dumb
# 8804               Zombieland
# 8805                     Zoom
# 8806                   Zubaan
# Name: title, Length: 8807, dtype: object

# %%
data.loc[:,['title','country']]
# Out:
#                       title        country
# 0      Dick Johnson Is Dead  United States
# 1             Blood & Water   South Africa
# 2                 Ganglands            NaN
# 3     Jailbirds New Orleans            NaN
# 4              Kota Factory          India
# ...                     ...            ...
# 8802                 Zodiac  United States
# 8803            Zombie Dumb            NaN
# 8804             Zombieland  United States
# 8805                   Zoom  United States
# 8806                 Zubaan          India
#
# [8807 rows x 2 columns]

# %%
data.loc[:,['type']].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# dtype: int64

# %%
data.loc[1,'cast'].split(', ')
# Out:
# ['Ama Qamata',
#  'Khosi Ngema',
#  'Gail Mabalane',
#  'Thabang Molaba',
#  'Dillon Windvogel',
#  'Natasha Thahane',
#  'Arno Greeff',
#  'Xolile Tshabalala',
#  'Getmore Sithole',
#  'Cindy Mahlangu',
#  'Ryle De Morny',
#  'Greteli Fincham',
#  'Sello Maake Ka-Ncube',
#  'Odwa Gwanya',
#  'Mekaila Mathys',
#  'Sandi Schultz',
#  'Duane Williams',
#  'Shamilla Miller',
#  'Patrick Mofokeng']

# %%
len(data.loc[1,'cast'].split(', ')) 
#split ka kaam hai k jahan jahan ', ' wahan wahan array main daal de
# Out:
# 19

# %%
import numpy as np
data['cast'].isnull().sum()
# Out:
# 825

# %%
data.replace(to_replace=np.nan,value='None')
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water             None
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans             None
# 4         s5  TV Show           Kota Factory             None
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb             None
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                  None  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
data.loc[data['title']=='Kota Factory']
# Out:
#   show_id     type         title director  \
# 4      s5  TV Show  Kota Factory      NaN
#
#                                                 cast country  \
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
#
#            date_added  release_year rating   duration  \
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 4  In a city of coaching centers known to train I...

# %%
data.loc[data['title']!='Kota Factory']
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 5         s6  TV Show          Midnight Mass    Mike Flanagan
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
len(data.loc[data['release_year']>2020])
# Out:
# 592

# %% [markdown]
# # ILOC

# %%
data.iloc[3:8,1:6]
# Out:
#       type                             title                       director  \
# 3  TV Show             Jailbirds New Orleans                            NaN
# 4  TV Show                      Kota Factory                            NaN
# 5  TV Show                     Midnight Mass                  Mike Flanagan
# 6    Movie  My Little Pony: A New Generation  Robert Cullen, José Luis Ucha
# 7    Movie                           Sankofa                   Haile Gerima
#
#                                                 cast  \
# 3                                                NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
#
#                                              country
# 3                                                NaN
# 4                                              India
# ...

# %% [markdown]
# # Group By : Similar values ko ek saath group krna

# %%
data.groupby('country')["rating"].value_counts()
# Out:
# country            rating
# , France, Algeria  TV-14      1
# , South Korea      TV-MA      1
# Argentina          TV-MA     39
#                    TV-14      7
#                    TV-PG      3
#                              ..
# Vietnam            TV-14      3
#                    TV-MA      3
#                    TV-G       1
# West Germany       TV-MA      1
# Zimbabwe           TV-G       1
# Name: rating, Length: 1175, dtype: int64

# %%
data.groupby('country')["rating","type"].count()
# Out:
# C:\Users\pc\AppData\Local\Temp/ipykernel_4632/1710493495.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('country')["rating","type"].count()
#                                                     rating  type
# country
# , France, Algeria                                        1     1
# , South Korea                                            1     1
# Argentina                                               56    56
# Argentina, Brazil, France, Poland, Germany, Den...       1     1
# Argentina, Chile                                         2     2
# ...                                                    ...   ...
# Venezuela                                                1     1
# Venezuela, Colombia                                      1     1
# Vietnam                                                  7     7
# West Germany                                             1     1
# ...
